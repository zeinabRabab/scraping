# %%
# %pip install linkedin-api
# Out:
# ...
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/147.9 kB ? eta -:--:--
#    -------- ------------------------------- 30.7/147.9 kB 93.5 kB/s eta 0:00:02
#    -------- ------------------------------- 30.7/147.9 kB 93.5 kB/s eta 0:00:02
#    -------- ------------------------------- 30.7/147.9 kB 93.5 kB/s eta 0:00:02
#    ----------- ---------------------------- 41.0/147.9 kB 75.7 kB/s eta 0:00:02
#    ----------- ---------------------------- 41.0/147.9 kB 75.7 kB/s eta 0:00:02
# ...

# %%
from linkedin_api import Linkedin
from personal_info import email,password #get email and password from personal_info file

api = Linkedin('email','passwoed')

# %%
#we need to get the public id of the LinkedIn account whose information we want to scrape.

info= api.get_profile('hardik-singh-0b9ab4225') 
print(info)
# Out:
# {'industryName': 'Software Development', 'lastName': 'Singh', 'locationName': 'India', 'student': False, 'geoCountryName': 'India', 'geoCountryUrn': 'urn:li:fs_geo:102713980', 'geoLocationBackfilled': False, 'elt': True, 'birthDate': {'month': 1, 'day': 14}, 'industryUrn': 'urn:li:fs_industry:4', 'firstName': 'Hardik', 'entityUrn': 'urn:li:fs_profile:ACoAADiU3o0BpIMjtuPu3LEwZgu6XmN8_zdNY3s', 'geoLocation': {'geoUrn': 'urn:li:fs_geo:109710172'}, 'geoLocationName': 'Bengaluru, Karnataka', 'location': {'basicLocation': {'countryCode': 'in'}}, 'headline': '--', 'displayPictureUrl': 'https://media.licdn.com/dms/image/D5603AQGJNbzDWfElAA/profile-displayphoto-shrink_', 'img_100_100': '100_100/0/1715875347976?e=1726704000&v=beta&t=eiJvlFltfZ6f6zeTbkSltrvGcJwHDGwobR2j_GR8At0', 'img_200_200': '200_200/0/1715875347976?e=1726704000&v=beta&t=KZNsWB_f222m3Qbs-4EdWrAAygoWj-xX6LkVfjj1O4I', 'img_400_400': '400_400/0/1715875347976?e=1726704000&v=beta&t=wUiw543y06SY7kTxi7k24CfqoBwD6TWKpvtDF-r8Bus', 'im
# ...

# %%
info.keys()
# Out:
# dict_keys(['industryName', 'lastName', 'locationName', 'student', 'geoCountryName', 'geoCountryUrn', 'geoLocationBackfilled', 'elt', 'birthDate', 'industryUrn', 'firstName', 'entityUrn', 'geoLocation', 'geoLocationName', 'location', 'headline', 'displayPictureUrl', 'img_100_100', 'img_200_200', 'img_400_400', 'img_646_646', 'profile_id', 'profile_urn', 'member_urn', 'public_id', 'experience', 'education', 'languages', 'publications', 'certifications', 'volunteer', 'honors', 'projects', 'skills', 'urn_id'])

# %%
print(info['education'])
# Out:
# [{'entityUrn': 'urn:li:fs_education:(ACoAADiU3o0BpIMjtuPu3LEwZgu6XmN8_zdNY3s,785025469)', 'school': {'objectUrn': 'urn:li:school:3244736', 'entityUrn': 'urn:li:fs_miniSchool:3244736', 'active': True, 'schoolName': 'Delhi Public School - India', 'trackingId': 'ukLXdZ0wQEaQRk9g4S0G6A==', 'logoUrl': 'https://media.licdn.com/dms/image/C510BAQFJWBCrV-fjMg/company-logo_'}, 'timePeriod': {'endDate': {'month': 3, 'year': 2024}, 'startDate': {'month': 3, 'year': 2009}}, 'schoolName': 'Delhi Public School - India', 'schoolUrn': 'urn:li:fs_miniSchool:3244736'}]

# %%
print(info['firstName'], info['lastName'], info['skills'])
# Out:
# Hardik Singh [{'name': 'Python (Programming Language)'}, {'name': 'Automation'}, {'name': 'Artificial Intelligence (AI)'}]

# %%
import csv

csv_file= 'linkedin_profiles.csv'

# Define CSV column headers
fields = list(info.keys())
with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=fields)
    
    writer.writeheader()  # Write header row
    
    writer.writerow(info)  # Write data rows

print(f'CSV file {csv_file} has been created successfully.')
# Out:
# CSV file linkedin_profiles.csv has been created successfully.
